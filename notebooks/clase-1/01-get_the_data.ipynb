# %%
# Montamos nuestro google drive en el colab

from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Linkeamos la data del curso a nuestro drive
#
# Ir a [este](https://drive.google.com/drive/u/0/folders/1hGGnpDKD9VT6-snpzLPLe9BN6qtb1uqy) drive y agregar un shortcut
#
# <img height="300" src="data:image/png;base64,..." />

# %%
DATA_HOME = r"/content/gdrive/My Drive/ml-practico-data"

# %%
# !ls "$DATA_HOME" # deberiamos ver los archivos de la captura de arriba
# Out:
# movie_gross.csv      title.crew.tsv.gz	      title.ratings.tsv.gz
# name.basics.tsv.gz   title.episode.tsv.gz
# title.basics.tsv.gz  title.principals.tsv.gz

# %%
import pandas as pd

# Probamos leer un archivo
df = pd.read_csv(
    DATA_HOME + "/name.basics.tsv.gz", 
    compression='gzip', delimiter='\t'
)

df.head()
# Out:
#       nconst      primaryName birthYear deathYear  \
# 0  nm0000001     Fred Astaire      1899      1987
# 1  nm0000002    Lauren Bacall      1924      2014
# 2  nm0000003  Brigitte Bardot      1934        \N
# 3  nm0000004     John Belushi      1949      1982
# 4  nm0000005   Ingmar Bergman      1918      2007
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0072308,tt0031983,tt0050419,tt0053137
# 1  tt0117057,tt0038355,tt0037382,tt0071877
# 2  tt0056404,tt0049189,tt0057345,tt0054452
# 3  tt0072562,tt0080455,tt0078723,tt0077975
# 4  tt0060827,tt0050986,tt0050976,tt0083922
