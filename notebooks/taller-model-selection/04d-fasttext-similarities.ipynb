# %%
# !pip install fasttext # necesario para importar los modulos
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 68 kB 3.1 MB/s
# ...
#   Using cached pybind11-2.10.1-py3-none-any.whl (216 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.2-cp37-cp37m-linux_x86_64.whl size=3161050 sha256=8768a8b7c319d816bf2d406e9ccded09547420872d1acfdf89a5fe6ba61fc0d2
#   Stored in directory: /root/.cache/pip/wheels/4e/ca/bf/b020d2be95f7641801a6597a29c8f4f19e38f9c02a345bab9b
# Successfully built fasttext
# ...
# Cloning into 'ml-practico-2022'...
# remote: Enumerating objects: 385, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 385 (delta 48), reused 42 (delta 20), pack-reused 313
# Receiving objects: 100% (385/385), 4.83 MiB | 24.39 MiB/s, done.
# Resolving deltas: 100% (239/239), done.

# %%
import sys
from google.colab import drive

sys.path.append('ml-practico-2022/lib')
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import fasttext

ft = fasttext.load_model('/content/gdrive/MyDrive/taller-model-selection-data/title_fasttext.bin')

# %%
ft.get_subwords('departamento')
# Out:
# (['departamento',
#   '<de',
#   '<dep',
#   '<depa',
#   '<depar',
#   'dep',
#   'depa',
#   'depar',
#   'depart',
#   'epa',
#   'epar',
#   'epart',
#   'eparta',
#   'par',
#   'part',
#   'parta',
#   'partam',
#   'art',
#   'arta',
#   'artam',
#   'artame',
#   'rta',
#   'rtam',
#   'rtame',
#   'rtamen',
#   'tam',
#   'tame',
#   'tamen',
#   'tament',
#   'ame',
#   'amen',
#   'ament',
#   'amento',
#   'men',
#   'ment',
#   'mento',
#   'mento>',
#   'ent',
#   'ento',
#   'ento>',
#   'nto',
#   'nto>',
#   'to>'],
#  array([     63, 1208116, 1706196,  947767, 1111015, 1911378,  867089,
#         1821473,  755711, 1061951,  467999,  616177, 1307128,  632228,
#          301008, 1369451,  137890, 1858246, 1690669, 1014480, 1922207,
#          178514, 1144157,  292680, 1806466, 1827469, 1794840,  654962,
#          588450, 1957438, 1994944,  742796, 1539049, 1629351,  738569,
#          194626, 1839460,  211094, 1723819,  242623, 1010316,  344934,
#         1846186]))

# %%
from random import choice

for i in range(30):
  w = choice(ft.words)
  print(w)
  for sim, word_sim in ft.get_nearest_neighbors(w, k=10):
    print('\t', word_sim, sim)
# Out:
# cdra
# 	 1cdra 0.816608726978302
# 	 cuadra 0.7050354480743408
# 	 cdras 0.6815621852874756
# 	 Cuadra 0.6640486121177673
# 	 sabattiniventa 0.6639726161956787
# 	 plaza 0.5946208238601685
# 	 mtrs) 0.5904807448387146
# 	 Av, 0.5826634764671326
# 	 Jerónimo 0.5798261761665344
# 	 Ob. 0.5764511823654175
# ALQUILADA
# 	 ALQUILAN 0.8469305038452148
# 	 ALQUILAR 0.8323512077331543
# 	 ALQUILA-Casa 0.823074996471405
# 	 ALQUILA! 0.8207773566246033
# 	 ALQUILA. 0.8204286694526672
# 	 ALQUILA, 0.8178647756576538
# 	 ALQUILADO 0.8112253546714783
# 	 ALQUILARUIZ 0.8067195415496826
# 	 ALQUILA: 0.8043590784072876
# 	 ALQUILAMOS 0.78211510181427
# elena
# 	 elena, 0.8385131359100342
# 	 lucia 0.6924718618392944
# 	 llena 0.684363603591919
# 	 emilia 0.676725447177887
# 	 haras 0.6716502904891968
# 	 Cº 0.666638195514679
# 	 Elena 0.6621461510658264
# 	 ElenaExcelente 0.6584031581878662
# 	 PilarSusana 0.6552900671958923
# 	 vena 0.6546924710273743
# Cuadra
# 	 Cuadras 0.7904410362243652
# ...
