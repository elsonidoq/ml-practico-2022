# %% [markdown]
# Para poder acceder a los datos es necesario seguir estos pasos
#
# 1. Ir a este [link de google drive](https://drive.google.com/drive/u/0/folders/1djjceNkO42vrB10PubYTzQydfccPbzdB)
# 2. Agregarlo como shortcut a tu google drive
#
# ![image.png](attachment:image.png)
